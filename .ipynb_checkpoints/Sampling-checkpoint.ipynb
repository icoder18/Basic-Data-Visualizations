# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_big=pd.read_csv('data/obama_too_big.csv',parse_dates=['year_month'])
data=pd.read_csv('data/obama.csv',parse_dates=['year_month'])

# %%
data_big.head()
# Out:
#   year_month survey_organization  approve_percent  disapprove_percent
# 0 2009-01-01      Generated Data             67.0                31.0
# 1 2009-01-01      Harris (Phone)             60.0                29.0
# 2 2009-01-01      Generated Data             65.9                19.1
# 3 2009-01-01      Generated Data             64.6                18.4
# 4 2009-01-01      Generated Data             83.3                11.7

# %%
data.head()
# Out:
#   year_month  survey_organization  approve_percent  disapprove_percent
# 0 2009-01-01             ABC/Post             80.0                15.0
# 1 2009-01-01               AP-GFK             74.0                15.0
# 2 2009-01-01                  CNN             84.0                14.0
# 3 2009-01-01  Democracy Corps (D)             51.0                20.0
# 4 2009-01-01       Diageo/Hotline             64.0                 6.5

# %%
data.shape
# Out:
# (1530, 4)

# %%
data_big.shape
# Out:
# (65499, 4)

# %%
plt.scatter(data_big.year_month,data_big.approve_percent,3,marker='o',alpha=0.3)
plt.show()

# %%
sample=data_big.sample(frac=0.1)
#Sample 10% of the data (fraction 10%)
#sample=data_big.sample(n=10000)
#mention no of rows in sample using n=10000

# %%
plt.scatter(sample.year_month,sample.approve_percent,2,marker='o',alpha=0.3)
plt.show()

# %%
plt.scatter(data_big.year_month,data_big.disapprove_percent,2,marker='o',alpha=0.3)
plt.show()

# %%
new_sample=data_big.sample(frac=0.1)

# %%
plt.scatter(new_sample.year_month,new_sample.disapprove_percent,2,marker='o',alpha=0.3)
plt.show()
