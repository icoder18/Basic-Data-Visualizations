# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("data/countries.csv")

# %%
data.head()
# Out:
#        country continent  year  lifeExpectancy  population  gdpPerCapita
# 0  Afghanistan      Asia  1952          28.801     8425333    779.445314
# 1  Afghanistan      Asia  1957          30.332     9240934    820.853030
# 2  Afghanistan      Asia  1962          31.997    10267083    853.100710
# 3  Afghanistan      Asia  1967          34.020    11537966    836.197138
# 4  Afghanistan      Asia  1972          36.088    13079460    739.981106

# %%
us=data[data.country=='United States']
us.head()
# Out:
#             country continent  year  lifeExpectancy  population  gdpPerCapita
# 1608  United States  Americas  1952           68.44   157553000   13990.48208
# 1609  United States  Americas  1957           69.49   171984000   14847.12712
# 1610  United States  Americas  1962           70.21   186538000   16173.14586
# 1611  United States  Americas  1967           70.76   198712000   19530.36557
# 1612  United States  Americas  1972           71.34   209896000   21806.03594

# %%
plt.plot(us.year,us.gdpPerCapita)
plt.title("GDP Per Capita Growth in the United States")
plt.xlabel("Year")
plt.ylabel("GDP Per Capita")
plt.show()

# %%
china=data[data.country=='China']
china.head()
# Out:
#     country continent  year  lifeExpectancy  population  gdpPerCapita
# 288   China      Asia  1952        44.00000   556263527    400.448611
# 289   China      Asia  1957        50.54896   637408000    575.987001
# 290   China      Asia  1962        44.50136   665770000    487.674018
# 291   China      Asia  1967        58.38112   754550000    612.705693
# 292   China      Asia  1972        63.11888   862030000    676.900092

# %%
plt.plot(us.year,us.gdpPerCapita,label="United States")
plt.title("GDP Per Capita Growth")
plt.xlabel("Year")
plt.ylabel("GDP Per Capita")
plt.plot(china.year,china.gdpPerCapita,label="China")
plt.legend()
plt.show()

# %%
us_growth=us.gdpPerCapita/us.gdpPerCapita.iloc[0]*100

# %%
china_growth=china.gdpPerCapita/china.gdpPerCapita.iloc[0]*100

# %%
plt.plot(us.year,us_growth,label="United States")
plt.plot(china.year,china_growth,label="China")
plt.title("GDP Per Capita Growth Over Years (first year=100)")
plt.xlabel("Year")
plt.ylabel("GDP Per Capita")
plt.legend()
plt.show()

# %% [markdown]
# ## Compare Population Growth in the U.S. and China

# %%
plt.title("Population Over Years (in millions)")
plt.xlabel("Year")
plt.ylabel("Population")
plt.plot(us.year,us.population/10**6,label='US')
plt.plot(china.year,china.population/10**6,label='China')
plt.legend()
plt.show()

# %%
china_population=china.population/china.population.iloc[0]*100
us_population=us.population/us.population.iloc[0]*100

# %%
plt.title("Population Growth Over Years (first year=100)")
plt.xlabel("Year")
plt.ylabel("Population")
plt.plot(us.year,us_population,label="US")
plt.plot(china.year,china_population,label="China")
plt.legend()
plt.show()
